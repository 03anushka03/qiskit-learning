# %%
from qiskit import QuantumCircuit
qc=QuantumCircuit(3,3)
qc.draw()
# Out:
#
# q_0:
#
# q_1:
#
# q_2:
#
# c: 3/

# %%
from qiskit import QuantumCircuit
qc=QuantumCircuit(3,3)
qc.measure([0,1,2],[0,1,2])
qc.draw()
# Out:
#      ┌─┐
# q_0: ┤M├──────
#      └╥┘┌─┐
# q_1: ─╫─┤M├───
#       ║ └╥┘┌─┐
# q_2: ─╫──╫─┤M├
#       ║  ║ └╥┘
# c: 3/═╩══╩══╩═
#       0  1  2

# %%
from qiskit_aer import AerSimulator
sim=AerSimulator()
job=sim.run(qc)
result=job.result()
result.get_counts()
# Out:
# {'000': 1024}

# %%
pip install qiskit_aer
# Out:
# Requirement already satisfied: qiskit_aer in c:\users\anushka\.venv\lib\site-packages (0.17.2)
# Requirement already satisfied: qiskit>=1.1.0 in c:\users\anushka\.venv\lib\site-packages (from qiskit_aer) (2.2.3)
# Requirement already satisfied: numpy>=1.16.3 in c:\users\anushka\.venv\lib\site-packages (from qiskit_aer) (2.3.5)
# Requirement already satisfied: scipy>=1.0 in c:\users\anushka\.venv\lib\site-packages (from qiskit_aer) (1.16.3)
# Requirement already satisfied: psutil>=5 in c:\users\anushka\.venv\lib\site-packages (from qiskit_aer) (7.1.3)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\anushka\.venv\lib\site-packages (from qiskit_aer) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\anushka\.venv\lib\site-packages (from python-dateutil>=2.8.0->qiskit_aer) (1.17.0)
# Requirement already satisfied: rustworkx>=0.15.0 in c:\users\anushka\.venv\lib\site-packages (from qiskit>=1.1.0->qiskit_aer) (0.17.1)
# Requirement already satisfied: dill>=0.3 in c:\users\anushka\.venv\lib\site-packages (from qiskit>=1.1.0->qiskit_aer) (0.4.0)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\anushka\.venv\lib\site-packages (from qiskit>=1.1.0->qiskit_aer) (5.6.0)
# Requirement already satisfied: typing-extensions in c:\users\anushka\.venv\lib\site-packages (from qiskit>=1.1.0->qiskit_aer) (4.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
qc=QuantumCircuit(3,3)
qc.x([2])
qc.measure([0,1,2],[0,1,2])
qc.draw()
# Out:
#           ┌─┐
# q_0: ─────┤M├──────
#           └╥┘┌─┐
# q_1: ──────╫─┤M├───
#      ┌───┐ ║ └╥┘┌─┐
# q_2: ┤ X ├─╫──╫─┤M├
#      └───┘ ║  ║ └╥┘
# c: 3/══════╩══╩══╩═
#            0  1  2

# %%
sim=AerSimulator()
job=sim.run(qc)
result=job.result()
result.get_counts()
# Out:
# {'100': 1024}

# %%
qc=QuantumCircuit(2,2)
qc.x(0)
qc.cx(0,1)
qc.measure([0,1],[0,1])
display(qc.draw('latex'))
sim=AerSimulator()
job=sim.run(qc)
result=job.result()
result.get_counts()
# Out:
# <PIL.Image.Image image mode=RGB size=284x99>
# {'11': 1024}

# %%
qc=QuantumCircuit(4,2)
qc.x(0)
qc.x(1)
qc.cx(0,2)
qc.cx(1,2)
qc.ccx(0,1,3)
qc.measure(2,0)
qc.measure(3,1)
display(qc.draw(output='mpl'))

job=sim.run(qc)
result=job.result()
result.get_counts()
# Out:
# {'10': 1024}

# %%
from qiskit.quantum_info import Statevector
qc=QuantumCircuit(2)
ket=Statevector(qc)
assert ket==Statevector.from_label('00')
ket.draw(output='latex')
# Out:
# $$ |00\rangle$$

# %%
qc=QuantumCircuit(2)
qc.x(1)
qc.cx(1,0)
ket=Statevector(qc)
ket.draw('latex')
# Out:
# $$ |11\rangle$$

# %%
qc=QuantumCircuit(2)
qc.h(1)
qc.cx(1,0)
ket=Statevector(qc)
ket.draw('latex')
# Out:
# $$\frac{\sqrt{2}}{2} |00\rangle+\frac{\sqrt{2}}{2} |11\rangle$$

# %%
qc=QuantumCircuit(2)
qc.h(0)
qc.h(1)
qc.z(0)
qc.cx(1,0)
ket=Statevector(qc)
assert ket==Statevector.from_label('--')
ket.draw('latex')
# Out:
# $$\frac{1}{2} |00\rangle- \frac{1}{2} |01\rangle- \frac{1}{2} |10\rangle+\frac{1}{2} |11\rangle$$

# %%
MESSAGE='00'
qc_alice=QuantumCircuit(2,2)
if MESSAGE[-1]==1:
   qc_alice.x(0)
if MESSAGE[-2]==1:
   qc_alice.x(1)

#qc_alice.draw('mpl')

# %%
from qiskit_aer import Aer
backend=Aer.get_backend('aer_simulator')
qc_bob=QuantumCircuit(2,2)
qc_bob.measure([0,1],[0,1])
backend.run(qc_alice.compose(qc_bob)).result().get_counts()
# Out:
# {'00': 1024}

# %%
MESSAGE='00'
qc_alice=QuantumCircuit(2)
if MESSAGE[-1]==1:
    qc_alice.x(0)
if MESSAGE[-2]==1:
    qc_alice.x(1)
qc_alice.h(1)
qc_alice.cx(1,0)
#qc.draw('mpl')
ket=Statevector(qc_alice)
ket.draw('latex')
# Out:
# $$\frac{\sqrt{2}}{2} |00\rangle+\frac{\sqrt{2}}{2} |11\rangle$$

# %%
qc_bob=QuantumCircuit(2,2)
qc_bob.cx(1,0)
qc_bob.h(1)
qc_bob.measure([0,1],[0,1])
qc_bob.draw('mpl')

# %%
MESSAGE='00'
qc_alice=QuantumCircuit(2,2)
qc_alice.h(1)
qc_alice.cx(1,0)
if MESSAGE[-2]==1:
    qc_alice.z(1)
if MESSAGE[-1]==1:
    qc_alice.x(1)
ket=Statevector(qc_alice)
ket.draw('latex')
# Out:
# $$\frac{\sqrt{2}}{2} |00\rangle+\frac{\sqrt{2}}{2} |11\rangle$$

# %%
backend.run(qc_alice.compose(qc_bob)).result().get_counts()
# Out:
# {'00': 1024}

# %%
qc_charlie=QuantumCircuit(2,2)
qc_charlie.h(1)
qc_charlie.cx(1,0)
qc_charlie.draw('mpl')

# %%
MESSAGE = '01'
qc_alice = QuantumCircuit(2,2)
if MESSAGE[-2]=='1':
    qc_alice.z(1)
if MESSAGE[-1]=='1':
    qc_alice.x(1)

# %%
backend.run(qc_charlie.compose(qc_alice.compose(qc_bob))).result().get_counts()
# Out:
# {'01': 1024}

# %%
meas_x=QuantumCircuit(1,1)
meas_x.h(0)
meas_x.measure(0,0)
meas_x.draw('mpl')

# %%
meas_z=QuantumCircuit(1,1)
meas_z.measure(0,0)
meas_z.draw('mpl')

# %%
qc=QuantumCircuit(1,1)
qc.draw('mpl')

# %%
backend.run(qc.compose(meas_z)).result().get_counts()
# Out:
# {'0': 1024}

# %%
backend.run(qc.compose(meas_x)).result().get_counts()
# Out:
# {'0': 505, '1': 519}

# %%
qc=QuantumCircuit(1,1)
qc.x(0)
qc.draw('mpl')

# %%
for basis, circ in [('z', meas_z),('x', meas_x)]:
    print("Results from ", basis, " measurement: ", backend.run(qc.compose(circ)).result().get_counts())
# Out:
# Results from  z  measurement:  {'1': 1024}
# Results from  x  measurement:  {'1': 498, '0': 526}

# %%
qc=QuantumCircuit(1,1)
qc.h(0)
qc.draw('mpl')

# %%
for basis, circ in [('z', meas_z), ('x', meas_x)]:
    print("Results from ", basis, " measurement: ", backend.run(qc.compose(circ)).result().get_counts())
# Out:
# Results from  z  measurement:  {'0': 517, '1': 507}
# Results from  x  measurement:  {'0': 1024}

# %%
from math import pi
qc=QuantumCircuit(1,1)
qc.ry(pi/4,0)
qc.draw('mpl')

# %%
for basis, circ in [('z', meas_z), ('x', meas_x)]:
    print("Results from ", basis, " measurement: ", backend.run(qc.compose(circ)).result().get_counts())
# Out:
# Results from  z  measurement:  {'0': 874, '1': 150}
# Results from  x  measurement:  {'0': 885, '1': 139}

# %%
qc_charlie=QuantumCircuit(2,2)
qc_charlie.ry(1.911,1)
qc_charlie.cx(1,0)
qc_charlie.ry(0.785,0)
qc_charlie.cx(1,0)
qc_charlie.ry(2.356,0)

qc_charlie.draw('mpl')

# %%
meas_zz=QuantumCircuit(2,2)
meas_zz.measure([0,1],[0,1])

# %%
from qiskit.visualization import plot_histogram
counts=backend.run(qc_charlie.compose(meas_zz)).result().get_counts()
plot_histogram(counts)

# %%
meas_xz=QuantumCircuit(2,2)
meas_xz.h(1)
meas_xz.measure([0,1],[0,1])
counts=backend.run(qc_charlie.compose(meas_xz)).result().get_counts()
plot_histogram(counts)

# %%
meas_xx=QuantumCircuit(2,2)
meas_xx.h([0,1])
meas_xx.measure([0,1],[0,1])
counts=backend.run(qc_charlie.compose(meas_xx)).result().get_counts()
plot_histogram(counts)
